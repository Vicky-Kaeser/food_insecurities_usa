# %%
import pandas as pd

# %%
df = pd.read_csv("food_access_research_atlas.csv")

# %%
df.head()
# Out:
#    CensusTract    State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0   1001020100  Alabama  Autauga      1     1912      693                  0
# 1   1001020200  Alabama  Autauga      1     2170      743                  0
# 2   1001020300  Alabama  Autauga      1     3373     1256                  0
# 3   1001020400  Alabama  Autauga      1     4386     1722                  0
# 4   1001020500  Alabama  Autauga      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  TractSeniors  TractWhite  \
# 0         0  0.000000                  0  ...           221        1622
# 1       181  0.083410                  0  ...           214         888
# 2         0  0.000000                  0  ...           439        2576
# 3         0  0.000000                  0  ...           904        4086
# 4       181  0.016812                  0  ...          1126        8666
#
# ...

# %%
for name in df.columns:
    print(name)
# Out:
# CensusTract
# State
# County
# Urban
# POP2010
# OHU2010
# GroupQuartersFlag
# NUMGQTRS
# PCTGQTRS
# LILATracts_1And10
# LILATracts_halfAnd10
# LILATracts_1And20
# LILATracts_Vehicle
# HUNVFlag
# LowIncomeTracts
# PovertyRate
# MedianFamilyIncome
# LA1and10
# LAhalfand10
# LA1and20
# LATracts_half
# LATracts1
# LATracts10
# LATracts20
# LATractsVehicle_20
# LAPOP1_10
# LAPOP05_10
# LAPOP1_20
# LALOWI1_10
# LALOWI05_10
# LALOWI1_20
# lapophalf
# lapophalfshare
# lalowihalf
# lalowihalfshare
# lakidshalf
# lakidshalfshare
# laseniorshalf
# laseniorshalfshare
# lawhitehalf
# lawhitehalfshare
# lablackhalf
# lablackhalfshare
# laasianhalf
# laasianhalfshare
# lanhopihalf
# lanhopihalfshare
# laaianhalf
# laaianhalfshare
# laomultirhalf
# laomultirhalfshare
# lahisphalf
# lahisphalfshare
# lahunvhalf
# lahunvhalfshare
# lasnaphalf
# lasnaphalfshare
# lapop1
# lapop1share
# lalowi1
# lalowi1share
# lakids1
# lakids1share
# laseniors1
# laseniors1share
# lawhite1
# lawhite1share
# lablack1
# ...

# %%
df[(df.State =='Kentucky') &(df.County =='Jefferson')]
# Out:
#        CensusTract     State     County  Urban  POP2010  OHU2010  \
# 27601  21111000200  Kentucky  Jefferson      1     2924     1007
# 27602  21111000300  Kentucky  Jefferson      1     2624     1012
# 27603  21111000400  Kentucky  Jefferson      1     4531     1833
# 27604  21111000600  Kentucky  Jefferson      1     1860      719
# 27605  21111000700  Kentucky  Jefferson      1     2626     1069
# ...            ...       ...        ...    ...      ...      ...
# 27787  21111012703  Kentucky  Jefferson      1     6069     2304
# 27788  21111012801  Kentucky  Jefferson      1     3256     1345
# 27789  21111012802  Kentucky  Jefferson      1     2543     1072
# 27790  21111013100  Kentucky  Jefferson      1     2066      870
# 27791  21111980100  Kentucky  Jefferson      0        0        0
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 27601                  0       227  0.077633                  0  ...
# ...

# %%
df[~(df.POP2010 ==0)]
# Out:
#        CensusTract    State    County  Urban  POP2010  OHU2010  \
# 0       1001020100  Alabama   Autauga      1     1912      693
# 1       1001020200  Alabama   Autauga      1     2170      743
# 2       1001020300  Alabama   Autauga      1     3373     1256
# 3       1001020400  Alabama   Autauga      1     4386     1722
# 4       1001020500  Alabama   Autauga      1    10766     4082
# ...            ...      ...       ...    ...      ...      ...
# 72859  56043000200  Wyoming  Washakie      0     3326     1317
# 72860  56043000301  Wyoming  Washakie      1     2665     1154
# 72861  56043000302  Wyoming  Washakie      1     2542     1021
# 72862  56045951100  Wyoming    Weston      0     3314     1322
# 72863  56045951300  Wyoming    Weston      1     3894     1699
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                      0         0  0.000000                  0  ...
# ...

# %%
clean_df = df[~(df.POP2010 ==0)].copy()

# %%
clean_df
# Out:
#        CensusTract    State    County  Urban  POP2010  OHU2010  \
# 0       1001020100  Alabama   Autauga      1     1912      693
# 1       1001020200  Alabama   Autauga      1     2170      743
# 2       1001020300  Alabama   Autauga      1     3373     1256
# 3       1001020400  Alabama   Autauga      1     4386     1722
# 4       1001020500  Alabama   Autauga      1    10766     4082
# ...            ...      ...       ...    ...      ...      ...
# 72859  56043000200  Wyoming  Washakie      0     3326     1317
# 72860  56043000301  Wyoming  Washakie      1     2665     1154
# 72861  56043000302  Wyoming  Washakie      1     2542     1021
# 72862  56045951100  Wyoming    Weston      0     3314     1322
# 72863  56045951300  Wyoming    Weston      1     3894     1699
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                      0         0  0.000000                  0  ...
# ...

# %%
clean_df.POP2010.describe()
# Out:
# count    72531.000000
# mean      4256.739022
# std       1955.987626
# min          1.000000
# 25%       2899.000000
# 50%       4011.000000
# 75%       5330.500000
# max      37452.000000
# Name: POP2010, dtype: float64

# %%
##?pd.DataFrame.drop
##?pd.read_csv

# %%
import matplotlib.pyplot as plt

# %%
clean_df.POP2010.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
clean_df.POP2010[clean_df.POP2010 <17500].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
clean_df[(clean_df.POP2010 <=10)]
# Out:
#        CensusTract       State       County  Urban  POP2010  OHU2010  \
# 105     1015981901     Alabama      Calhoun      0        6        5
# 106     1015981902     Alabama      Calhoun      0        5        2
# 2374    4013980700     Arizona     Maricopa      0        4        2
# 3355    5119003205    Arkansas      Pulaski      1        2        2
# 7045    6037980003  California  Los Angeles      0        2        1
# ...            ...         ...          ...    ...      ...      ...
# 68345  51107980100    Virginia      Loudoun      1        2        1
# 68876  51590980100    Virginia     Danville      0        2        2
# 69105  51710980200    Virginia      Norfolk      1        5        4
# 69106  51710980300    Virginia      Norfolk      1        1        1
# 69445  53005012000  Washington       Benton      0        5        3
#
#        GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# ...

# %%
fix_some_columns = {
    'LILATracts_1And10': 'low_income_low_access_tract_1_mile_urban_10_miles_rural',
    'LILATracts_halfAnd10': 'low_income_low_access_tract_1/2_mile_urban_10_miles_rural',
    'LILATracts_1And20': 'low_income_low_access_tract_1_mile_urban_20_miles_rural',
    'LILATracts_Vehicle': 'low_income_low_access_tract_vehicle_use_20_miles' 
}

# %%
###LILATracts_1And10 shows as 'low_income_low_access_tract_1_mile_urban_10_miles_rural' ###
clean_df.rename(columns=fix_some_columns, inplace=True)
clean_df.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'Urban', 'POP2010', 'OHU2010',
#        'GroupQuartersFlag', 'NUMGQTRS', 'PCTGQTRS',
#        'low_income_low_access_tract_1_mile_urban_10_miles_rural',
#        ...
#        'TractSeniors', 'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI',
#        'TractAIAN', 'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP'],
#       dtype='object', length=147)

# %%
clean_df.County.unique()
# Out:
# array(['Autauga', 'Baldwin', 'Barbour', ..., 'Uinta', 'Washakie',
#        'Weston'], dtype=object)

# %%
###df[df.street.str.contains('null')].head()
df.street.replace({' null':''}, regex=True,inplace=True)
df[df.street.str.contains('null')].head()###
